# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn import metrics
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import xgboost as xgb
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('data.csv', sep=';')
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
# 4                           100.0            1                      37
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                      12  ...                                    0
# 1                       3  ...                                    0
# 2                      37  ...                                    0
# 3                      37  ...                                    0
# 4                      38  ...                                    0
#
#    Curricular units 2nd sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
# 3            -0.8 -3.12  Graduate
# 4            -0.3  0.79  Graduate
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (4424, 37)

# %%
# Check the proportion of each target in the population
df['Target'].value_counts()/df.shape[0]
# Out:
# Target
# Graduate    0.499322
# Dropout     0.321203
# Enrolled    0.179476
# Name: count, dtype: float64

# %%
# columns referred as likely to affect results in the EDA part and we only keep those part for modelling
likely_cls = ['Marital status','Application mode','Course','Previous qualification','Nacionality',
              "Father's qualification", "Mother's occupation","Father's occupation",
              'Debtor','Tuition fees up to date','Scholarship holder','Curricular units 1st sem (enrolled)',
              'Curricular units 1st sem (evaluations)','Curricular units 1st sem (approved)',
              'Curricular units 1st sem (without evaluations)','Curricular units 2nd sem (credited)',
              'Curricular units 2nd sem (enrolled)','Curricular units 2nd sem (evaluations)',
              'Curricular units 2nd sem (approved)','Curricular units 2nd sem (without evaluations)',
             'Target']
#course: categorical

# %%
df_cleaned = df[likely_cls]
df_cleaned.head()
# Out:
#    Marital status  Application mode  Course  Previous qualification  \
# 0               1                17     171                       1
# 1               1                15    9254                       1
# 2               1                 1    9070                       1
# 3               1                17    9773                       1
# 4               2                39    8014                       1
#
#    Nacionality  Father's qualification  Mother's occupation  \
# 0            1                      12                    5
# 1            1                       3                    3
# 2            1                      37                    9
# 3            1                      37                    5
# 4            1                      38                    9
#
#    Father's occupation  Debtor  Tuition fees up to date  ...  \
# 0                    9       0                        1  ...
# 1                    3       0                        0  ...
# 2                    9       0                        0  ...
# 3                    3       0                        1  ...
# 4                    9       0                        1  ...
#
#    Curricular units 1st sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
#
#    Curricular units 1st sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                       8
# 4                                       9
#
#    Curricular units 1st sem (approved)  \
# 0                                    0
# 1                                    6
# 2                                    0
# 3                                    6
# 4                                    5
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  \
# 0                                    0
# 1                                    6
# 2                                    0
# 3                                    5
# 4                                    6
#
#    Curricular units 2nd sem (without evaluations)    Target
# 0                                               0   Dropout
# 1                                               0  Graduate
# 2                                               0   Dropout
# 3                                               0  Graduate
# 4                                               0  Graduate
#
# [5 rows x 21 columns]

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_cleaned.drop('Target', axis = 1), 
                                                    df_cleaned['Target'], test_size=0.2, 
                                                    random_state=42)

# %% [markdown]
# ### Decision Tree

# %%
df_cleaned
# Out:
#       Marital status  Application mode  Course  Previous qualification  \
# 0                  1                17     171                       1
# 1                  1                15    9254                       1
# 2                  1                 1    9070                       1
# 3                  1                17    9773                       1
# 4                  2                39    8014                       1
# ...              ...               ...     ...                     ...
# 4419               1                 1    9773                       1
# 4420               1                 1    9773                       1
# 4421               1                 1    9500                       1
# 4422               1                 1    9147                       1
# 4423               1                10    9773                       1
#
#       Nacionality  Father's qualification  Mother's occupation  \
# 0               1                      12                    5
# 1               1                       3                    3
# 2               1                      37                    9
# 3               1                      37                    5
# 4               1                      38                    9
# ...           ...                     ...                  ...
# 4419            1                       1                    5
# 4420          105                       1                    9
# 4421            1                      37                    9
# 4422            1                      37                    7
# 4423           22                      37                    5
#
#       Father's occupation  Debtor  Tuition fees up to date  ...  \
# 0                       9       0                        1  ...
# 1                       3       0                        0  ...
# 2                       9       0                        0  ...
# 3                       3       0                        1  ...
# 4                       9       0                        1  ...
# ...                   ...     ...                      ...  ...
# 4419                    4       0                        1  ...
# 4420                    9       1                        0  ...
# 4421                    9       0                        1  ...
# 4422                    4       0                        1  ...
# 4423                    9       0                        1  ...
#
#       Curricular units 1st sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       6
# 3                                       6
# 4                                       6
# ...                                   ...
# 4419                                    6
# 4420                                    6
# 4421                                    7
# 4422                                    5
# 4423                                    6
#
#       Curricular units 1st sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                          8
# 4                                          9
# ...                                      ...
# 4419                                       7
# 4420                                       6
# 4421                                       8
# 4422                                       5
# 4423                                       8
#
#       Curricular units 1st sem (approved)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                       6
# 4                                       5
# ...                                   ...
# 4419                                    5
# 4420                                    6
# 4421                                    7
# 4422                                    5
# 4423                                    6
#
#       Curricular units 1st sem (without evaluations)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 4419                                               0
# 4420                                               0
# 4421                                               0
# 4422                                               0
# 4423                                               0
#
#       Curricular units 2nd sem (credited)  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 4419                                    0
# 4420                                    0
# 4421                                    0
# 4422                                    0
# 4423                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       6
# 3                                       6
# 4                                       6
# ...                                   ...
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                         10
# 4                                          6
# ...                                      ...
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                       5
# 4                                       6
# ...                                   ...
# 4419                                    5
# 4420                                    2
# 4421                                    1
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (without evaluations)    Target
# 0                                                  0   Dropout
# 1                                                  0  Graduate
# 2                                                  0   Dropout
# 3                                                  0  Graduate
# 4                                                  0  Graduate
# ...                                              ...       ...
# 4419                                               0  Graduate
# 4420                                               0   Dropout
# 4421                                               0   Dropout
# 4422                                               0  Graduate
# 4423                                               0  Graduate
#
# [4424 rows x 21 columns]

# %%
preproc = ColumnTransformer(transformers =
    [
     ("one",OneHotEncoder(handle_unknown = 'ignore'),["Nacionality",'Course','Marital status',
                                                      'Application mode',"Father's occupation",
                                                     "Mother's occupation"])
    ],
    remainder = 'passthrough')

base = Pipeline([('preprocessor', preproc),
                 ('r', DecisionTreeClassifier(max_depth = 6,
                        criterion = "gini", min_samples_split = 100))])
base.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Nacionality', 'Course',
#                                                    'Marital status',
#                                                    'Application mode',
#                                                    "Father's occupation",
#                                                    "Mother's occupation"])])),
#                 ('r',
#                  DecisionTreeClassifier(max_depth=6, min_samples_split=100))])

# %%
base.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Nacionality', 'Course',
#                                                    'Marital status',
#                                                    'Application mode',
#                                                    "Father's occupation",
#                                                    "Mother's occupation"])])),
#                 ('r',
#                  DecisionTreeClassifier(max_depth=6, min_samples_split=100))])

# %%
predictions_dt = base.predict(X_test)
accuracy = accuracy_score(y_test, predictions_dt)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7367231638418079

# %%
error={}
error["train"] = f1_score(y_train, base.predict(X_train), average='macro')
error["test"] = f1_score(y_test, base.predict(X_test), average='macro')
error
# Out:
# {'train': 0.6956620305339202, 'test': 0.6437335788763421}

# %%
from sklearn.model_selection import GridSearchCV
hyperparameters = {
    'max_depth': [2, 3, 4, 5, 7, 10, 13, 15, 18, None], 
    'min_samples_split': [2, 5, 10, 20, 50, 100, 200],
    'criterion': ['gini', 'entropy']
}
X_train_m = preproc.transform(X_train)
searcher = GridSearchCV(DecisionTreeClassifier(), hyperparameters, cv=5)
searcher.fit(X_train_m, y_train)
searcher.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 100}

# %%
final = Pipeline([('preprocessor', preproc),
                  ('r', DecisionTreeClassifier(**searcher.best_params_))])
final.fit(X_train,y_train)
error={}
error["train"] = f1_score(y_train, final.predict(X_train), average='macro')
error["test"] = f1_score(y_test, final.predict(X_test), average='macro')
error
# Out:
# {'train': 0.7215309424304435, 'test': 0.6483387851870842}

# %%
from sklearn import metrics
metrics.plot_confusion_matrix(final, X_test, y_test)
# Out:
# /Users/ruijiezhong/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Logistic Regression

# %%
base_logistic = Pipeline([('preprocessor', preproc),
                 ('r', LogisticRegression())])

# %%
base_logistic.fit(X_train,y_train)
# Out:
# /Users/ruijiezhong/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Nacionality', 'Course',
#                                                    'Marital status',
#                                                    'Application mode',
#                                                    "Father's occupation",
#                                                    "Mother's occupation"])])),
#                 ('r', LogisticRegression())])

# %%
base_logistic.fit(X_train,y_train)
# Out:
# /Users/ruijiezhong/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Nacionality', 'Course',
#                                                    'Marital status',
#                                                    'Application mode',
#                                                    "Father's occupation",
#                                                    "Mother's occupation"])])),
#                 ('r', LogisticRegression())])

# %%
predictions_l = base_logistic.predict(X_test)
accuracy = accuracy_score(y_test, predictions_l)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7536723163841808

# %% [markdown]
# ### XgBoost

# %%
X = df.drop('Target', axis=1)  # Feature matrix
y = df['Target']  # Target variable

# Convert labels to numbers 
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Splitting dataset into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

xgb_clf = XGBClassifier(objective='multi:softmax', num_class=3, verbosity=1)

# Define our parameter grid
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],  # Smaller values make the model robust but slow to learn
    'max_depth': [4, 5, 6],  # Depth of the tree
    'min_child_weight': [1, 3, 5],  # Minimum sum of instance weight(hessian) needed in a child
    'eta':[0.3,0.5]
}

# Setup GridSearchCV
grid_search = GridSearchCV(estimator=xgb_clf, param_grid=param_grid, scoring='f1_weighted', n_jobs=-1, cv=3, verbose=3)

# Assuming X_train, y_train are defined as your feature matrix and target vector from your dataset
grid_search.fit(X_train, y_train)

# Best parameters and best score
print("Best parameters found: ", grid_search.best_params_)
print("Best F1 score found: ", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=5;, score=0.731 total time=   2.3s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=5;, score=0.723 total time=   2.4s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=3;, score=0.719 total time=   2.4s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=3;, score=0.729 total time=   2.4s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=1;, score=0.723 total time=   2.4s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=1;, score=0.734 total time=   2.4s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=1;, score=0.741 total time=   2.4s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=3;, score=0.745 total time=   2.4s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=4, min_child_weight=5;, score=0.744 total time=   2.5s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=3;, score=0.749 total time=   3.0s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=1;, score=0.747 total time=   3.1s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5;, score=0.745 total time=   3.0s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=3;, score=0.748 total time=   3.0s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=1;, score=0.746 total time=   3.1s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=3;, score=0.753 total time=   3.0s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=1;, score=0.757 total time=   3.2s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5;, score=0.753 total time=   2.9s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=5, min_child_weight=5;, score=0.748 total time=   3.1s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=3;, score=0.761 total time=   3.9s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=1;, score=0.751 total time=   3.9s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=1;, score=0.738 total time=   4.0s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=3;, score=0.738 total time=   4.0s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=1;, score=0.751 total time=   4.0s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=3;, score=0.752 total time=   3.9s
# [CV 1/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=5;, score=0.740 total time=   3.9s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3;, score=0.768 total time=   2.3s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=1;, score=0.762 total time=   2.4s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=1;, score=0.774 total time=   2.4s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=1;, score=0.761 total time=   2.4s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3;, score=0.770 total time=   2.3s
# [CV 2/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=5;, score=0.755 total time=   3.8s
# [CV 3/3] END eta=0.3, learning_rate=0.01, max_depth=6, min_child_weight=5;, score=0.748 total time=   3.7s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3;, score=0.760 total time=   2.5s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=5;, score=0.778 total time=   2.5s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=5;, score=0.757 total time=   2.5s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=4, min_child_weight=5;, score=0.763 total time=   2.5s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=1;, score=0.751 total time=   3.4s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=1;, score=0.763 total time=   3.4s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=1;, score=0.765 total time=   3.4s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=3;, score=0.754 total time=   3.5s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=3;, score=0.769 total time=   4.0s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5;, score=0.774 total time=   3.9s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5;, score=0.756 total time=   3.9s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=3;, score=0.763 total time=   3.9s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=5, min_child_weight=5;, score=0.772 total time=   4.0s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=1;, score=0.750 total time=   4.9s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=1;, score=0.761 total time=   5.0s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=1;, score=0.763 total time=   5.3s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=3;, score=0.764 total time=   5.3s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=3;, score=0.746 total time=   5.4s
# [CV 1/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5;, score=0.750 total time=   5.3s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=3;, score=0.762 total time=   5.4s
# [CV 2/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5;, score=0.767 total time=   5.0s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1;, score=0.756 total time=   3.6s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1;, score=0.770 total time=   3.2s
# [CV 3/3] END eta=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5;, score=0.766 total time=   4.9s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3;, score=0.762 total time=   2.7s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1;, score=0.760 total time=   2.7s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3;, score=0.766 total time=   2.7s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3;, score=0.766 total time=   2.7s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5;, score=0.763 total time=   2.6s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5;, score=0.759 total time=   2.6s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5;, score=0.761 total time=   2.5s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1;, score=0.757 total time=   3.4s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1;, score=0.762 total time=   3.4s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3;, score=0.766 total time=   3.3s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3;, score=0.751 total time=   3.4s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1;, score=0.760 total time=   3.4s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=3;, score=0.756 total time=   3.4s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=5;, score=0.753 total time=   3.4s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=5;, score=0.762 total time=   3.8s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=5, min_child_weight=5;, score=0.762 total time=   3.6s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3;, score=0.741 total time=   3.9s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1;, score=0.764 total time=   4.0s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1;, score=0.767 total time=   4.0s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1;, score=0.747 total time=   4.0s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3;, score=0.771 total time=   3.8s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3;, score=0.770 total time=   3.8s
# [CV 1/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5;, score=0.751 total time=   3.3s
# [CV 2/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5;, score=0.763 total time=   3.3s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=1;, score=0.734 total time=   2.3s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=1;, score=0.723 total time=   2.3s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=1;, score=0.741 total time=   2.3s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=3;, score=0.719 total time=   2.2s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=3;, score=0.729 total time=   2.2s
# [CV 3/3] END eta=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5;, score=0.769 total time=   3.3s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=3;, score=0.745 total time=   2.3s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=5;, score=0.723 total time=   2.6s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=5;, score=0.744 total time=   2.7s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=4, min_child_weight=5;, score=0.731 total time=   2.7s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=1;, score=0.747 total time=   3.4s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=1;, score=0.746 total time=   3.4s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=1;, score=0.757 total time=   3.4s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=3;, score=0.748 total time=   3.4s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=3;, score=0.749 total time=   3.3s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=3;, score=0.753 total time=   3.1s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=5;, score=0.753 total time=   3.0s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=5;, score=0.745 total time=   3.0s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=5, min_child_weight=5;, score=0.748 total time=   3.0s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=1;, score=0.738 total time=   3.9s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=1;, score=0.751 total time=   3.9s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=1;, score=0.751 total time=   3.9s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=3;, score=0.738 total time=   4.0s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=3;, score=0.761 total time=   4.1s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=3;, score=0.752 total time=   4.1s
# [CV 1/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=5;, score=0.740 total time=   4.1s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=1;, score=0.762 total time=   2.6s
# [CV 2/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=5;, score=0.755 total time=   4.0s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=1;, score=0.774 total time=   2.8s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=1;, score=0.761 total time=   2.7s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=3;, score=0.768 total time=   2.7s
# [CV 3/3] END eta=0.5, learning_rate=0.01, max_depth=6, min_child_weight=5;, score=0.748 total time=   4.1s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=3;, score=0.770 total time=   2.8s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=3;, score=0.760 total time=   2.8s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=5;, score=0.757 total time=   2.7s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=5;, score=0.778 total time=   2.7s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=4, min_child_weight=5;, score=0.763 total time=   2.6s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1;, score=0.751 total time=   3.3s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1;, score=0.763 total time=   3.1s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=1;, score=0.765 total time=   3.1s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=3;, score=0.769 total time=   2.9s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=3;, score=0.754 total time=   2.9s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=3;, score=0.763 total time=   2.9s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=5;, score=0.756 total time=   2.8s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=5;, score=0.774 total time=   2.7s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=5, min_child_weight=5;, score=0.772 total time=   2.7s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=1;, score=0.750 total time=   3.3s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=1;, score=0.761 total time=   3.3s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=3;, score=0.746 total time=   3.5s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=1;, score=0.763 total time=   3.6s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=3;, score=0.764 total time=   3.6s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=3;, score=0.762 total time=   3.6s
# [CV 1/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=5;, score=0.750 total time=   3.7s
# [CV 2/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=5;, score=0.767 total time=   3.8s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=1;, score=0.756 total time=   2.7s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=1;, score=0.770 total time=   2.5s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=1;, score=0.760 total time=   2.5s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=3;, score=0.762 total time=   2.4s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=3;, score=0.766 total time=   2.4s
# [CV 3/3] END eta=0.5, learning_rate=0.1, max_depth=6, min_child_weight=5;, score=0.766 total time=   3.8s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=3;, score=0.766 total time=   2.3s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=5;, score=0.759 total time=   2.2s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=5;, score=0.763 total time=   2.2s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=4, min_child_weight=5;, score=0.761 total time=   2.3s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=1;, score=0.757 total time=   2.9s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=1;, score=0.762 total time=   2.8s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=1;, score=0.760 total time=   2.9s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=3;, score=0.751 total time=   2.8s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=3;, score=0.766 total time=   2.8s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=3;, score=0.756 total time=   2.8s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=5;, score=0.753 total time=   2.8s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=5;, score=0.762 total time=   2.7s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=5, min_child_weight=5;, score=0.762 total time=   2.8s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=1;, score=0.747 total time=   3.5s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=1;, score=0.767 total time=   3.4s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=1;, score=0.764 total time=   3.4s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=3;, score=0.741 total time=   3.3s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=3;, score=0.771 total time=   3.2s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=3;, score=0.770 total time=   3.0s
# [CV 1/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=5;, score=0.751 total time=   2.8s
# [CV 2/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=5;, score=0.763 total time=   2.5s
# [CV 3/3] END eta=0.5, learning_rate=0.2, max_depth=6, min_child_weight=5;, score=0.769 total time=   1.9s
# Best parameters found:  {'eta': 0.3, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 5}
# Best F1 score found:  0.7673419083214993

# %%
best_params = grid_search.best_params_

# Create a new XGBClassifier instance with the best parameters
best_xgb_clf = XGBClassifier(objective='multi:softmax', num_class=3, verbosity=1, **best_params)

# Train the classifier on the entire training set
best_xgb_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.3, eval_metric=None,
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_class=3, num_parallel_tree=None, ...)

# %%
# Making predictions
predictions = best_xgb_clf.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy:.4f}')

f1 = f1_score(y_test, predictions, average='weighted')  # 'weighted' accounts for label imbalance.
print(f'F1 Score: {f1:.2f}')
# Out:
# Accuracy: 0.7627
# F1 Score: 0.75

# %%
cm = confusion_matrix(y_test, predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
xgb.plot_importance(best_xgb_clf)
plt.title('Feature Importance')
plt.show()
# Out:
# /Users/bobbyzhu/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### SVM

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import make_pipeline

# Creating a SVM classifier using the RBF kernel
param_grid = {
    'svm__C': [0.1, 1, 10],
    'svm__gamma': [0.001, 0.01, 0.1, 1],
    'svm__kernel': ['rbf', 'linear', 'poly']
}
# Create a pipeline that scales the data then applies SVM
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC())
])

# Create the GridSearchCV object
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))

# Predict with the best found parameters
y_pred = grid_search.predict(X_test)
print("Classification report for best parameters:")
print(classification_report(y_test, y_pred))
# Out:
# Best parameters: {'svm__C': 10, 'svm__gamma': 0.01, 'svm__kernel': 'rbf'}
# Best cross-validation score: 0.77
# Classification report for best parameters:
#               precision    recall  f1-score   support
#
#            0       0.87      0.75      0.80       316
#            1       0.47      0.37      0.41       151
#            2       0.77      0.91      0.84       418
#
#     accuracy                           0.76       885
#    macro avg       0.70      0.68      0.69       885
# weighted avg       0.76      0.76      0.75       885

# %%
best_params = grid_search.best_params_
adjusted_best_params = {key.replace('svm__', ''): value for key, value in best_params.items()}

# Create a new XGBClassifier instance with the best parameters
best_svm_clf = SVC(decision_function_shape='ovo',**adjusted_best_params)
# Train the classifier on the entire training set
best_svm_clf.fit(X_train, y_train)
print(f'Accuracy: {accuracy:.4f}')

f1 = f1_score(y_test, predictions, average='weighted')  # 'weighted' accounts for label imbalance.
print(f'F1 Score: {f1:.2f}')
# Out:
# Accuracy: 0.7627
# F1 Score: 0.75

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
